# %%
import numpy as np
import pandas as pd

# %%
import kagglehub
from kagglehub import KaggleDatasetAdapter

# Set the path to the file you'd like to load
file_path = "cars24data.csv"

# Load the latest version
df = kagglehub.load_dataset(
  KaggleDatasetAdapter.PANDAS,
  "amanrajput16/used-car-price-data-from-cars24",
  file_path,
  # Provide any additional arguments like 
  # sql_query or pandas_kwargs. See the 
  # documenation for more information:
  # https://github.com/Kaggle/kagglehub/blob/main/README.md#kaggledatasetadapterpandas
)

print("First 5 records:", df.head())
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20560\3950228486.py:8: DeprecationWarning: Use dataset_load() instead of load_dataset(). load_dataset() will be removed in a future version.
#   df = kagglehub.load_dataset(
# First 5 records:                             Model Name    Price  Manufacturing_year  \
# 0                2017 Maruti Swift VXI   561000                2017
# 1  2016 Maruti Baleno DELTA PETROL 1.2   498000                2016
# 2                2020 Maruti Swift VXI   577000                2020
# 3       2022 Maruti Ertiga VXI AT SHVS  1084000                2022
# 4                2019 Maruti Dzire VXI   603000                2019
#
#    Engine capacity Spare key Transmission  KM driven  Ownership Fuel type  \
# 0             1197        No       Manual      25847          2    Petrol
# 1             1197       Yes       Manual      55511          2    Petrol
# 2             1197        No       Manual      47110          1    Petrol
# ...

# %%
df.columns
# Out:
# Index(['Model Name', 'Price', 'Manufacturing_year', 'Engine capacity',
#        'Spare key', 'Transmission', 'KM driven', 'Ownership', 'Fuel type',
#        'Imperfections', 'Repainted Parts'],
#       dtype='str')

# %%
import matplotlib.pyplot as plt

# %%
x = [ 1,2,3,4,5]
y= [2,4,1,8,7]
sizes = [50,100,15,200,250]
colors = [50,30,100,600,200]
plt.scatter(x,y, s=sizes, c=colors)
plt.colorbar()
plt.title("scatter PLOT")
plt.xlabel("X")
plt.ylabel("Y")
plt.show()

# %%
x= df["Imperfections"]
y= df["Repainted Parts"]
size = df["Price"]//10000
plt.scatter(x,y, s=size, marker= "+")
plt.show()

# %%
##########################################################################
##################### Pie chart #########################################

# %%
values = df["Transmission"].value_counts().reset_index()
values.head()
# Out:
#   Transmission  count
# 0       Manual   1073
# 1    Automatic    372

# %%
plt.pie(values["count"], labels=values["Transmission"], autopct = "%1.1f%%", startangle = 90, )

plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt


plt.boxplot(df['Engine capacity'].values,
            
            whis =[0,100],      #to show the whiskerprops
            medianprops=dict(color="red"),
            whiskerprops=dict(color="brown"),
            capprops=dict(color="blue")  )
plt.show()

# %%
plt.boxplot(df[['Price','Engine capacity'] ].values,
            
            whis =[0,100],      #to show the whiskerprops
            medianprops=dict(color="red"),
            whiskerprops=dict(color="brown"),
            capprops=dict(color="blue")  )
plt.show()

# %%
plt.boxplot([df['Price'], df['Engine capacity']],
            labels=['Price', 'Engine capacity'])

plt.yscale('log')
plt.title("Boxplot with Log Scale")
plt.show()
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_20560\391235499.py:1: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot([df['Price'], df['Engine capacity']],

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
numric_col = df.select_dtypes(include = ["number"])
corr = numric_col.corr()
corr
# Out:
#                        Price  Manufacturing_year  Engine capacity  KM driven  \
# Price               1.000000            0.615077         0.718906  -0.308925
# Manufacturing_year  0.615077            1.000000         0.128797  -0.529817
# Engine capacity     0.718906            0.128797         1.000000   0.017436
# KM driven          -0.308925           -0.529817         0.017436   1.000000
# Ownership          -0.193696           -0.217609        -0.075150   0.183771
# Imperfections      -0.245968           -0.326156        -0.034947   0.266018
# Repainted Parts    -0.207350           -0.256837        -0.015830   0.249148
#
#                     Ownership  Imperfections  Repainted Parts
# Price               -0.193696      -0.245968        -0.207350
# Manufacturing_year  -0.217609      -0.326156        -0.256837
# Engine capacity     -0.075150      -0.034947        -0.015830
# KM driven            0.183771       0.266018         0.249148
# ...

# %%
sns.heatmap(
    corr,
    annot = True,
    cmap= "coolwarm",
    vmin =-1, vmax =1,
    linewidth = 0.5 
)

plt.title("heat map of carrolation")
plt.show()

# %%
df = sns.load_dataset('iris')

# plot
sns.violinplot(x=df["species"], y=df["sepal_length"])
# Out:
# <Axes: xlabel='species', ylabel='sepal_length'>

# %%
import gapminder as gapminder

# %%
data = gapminder.loc[gapminder.year == 2007]

# use the scatterplot function to build the bubble map
sns.scatterplot(data=data, x="gdpPercap", y="lifeExp", size="pop", legend=False, sizes=(20, 2000))

# show the graph
plt.show()
