# %%
pip install pandas
# Out:
# ...
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    ---------------------------------------- 0.0/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
#    - -------------------------------------- 0.3/9.7 MB ? eta -:--:--
# ...

# %%
import pandas as pd
import numpy as np

# %%
series = pd.Series([2,4,6,8])
series
# Out:
# 0    2
# 1    4
# 2    6
# 3    8
# dtype: int64

# %%
series = pd.Series([2,4,6,8] , index=["a", "b" ,"c" , "d"])
series.index.name = "my_index"


series
# Out:
# my_index
# a    2
# b    4
# c    6
# d    8
# dtype: int64

# %%
series.values
# Out:
# array([2, 4, 6, 8])

# %%
max(series.values)
# Out:
# np.int64(8)

# %%
indx = series.index
indx
# Out:
# Index([1, 2, 3, 4], dtype='int64')

# %%
import numpy as np

# %%
average = np.mean(series.values)
average
# Out:
# np.float64(5.0)

# %%
#update the index (labels of rows)

series = pd.Series([2,4,6,8] , index=["a", "b" ,"c" , "d"])
series.index =[1,2,3,4]
series.index.name ="new index"

series
# Out:
# new index
# 1    2
# 2    4
# 3    6
# 4    8
# dtype: int64

# %%
series[1]
# Out:
# np.int64(2)

# %%
series[series<6]
# Out:
# new index
# 1    2
# 2    4
# dtype: int64

# %%
3 in series
# Out:
# True

# %%
series.index =["a","b","c","d"]
series.index.name ="new index"
series
# Out:
# new index
# a    2
# b    4
# c    6
# d    8
# dtype: int64

# %%
"b" in series
# Out:
# True

# %%
#####convert series to dictionary
dic = series.to_dict()
print(dic)
# Out:
# {'a': 2, 'b': 4, 'c': 6, 'd': 8}

# %%
s_dic = pd.Series(dic)
s_dic
# Out:
# a    2
# b    4
# c    6
# d    8
# dtype: int64

# %%
################################################
###############################################

# %%
countriesPop = pd.Series([8700000,4300000,3000000,2100000], index = ['China','Germany','Japan','USA'])

countriesPop.name = "countriesPop"
pd.isnull(countriesPop)
# Out:
# China      False
# Germany    False
# Japan      False
# USA        False
# Name: countriesPop, dtype: bool

# %%
pd.notnull(countriesPop)
# Out:
# China      True
# Germany    True
# Japan      True
# USA        True
# Name: countriesPop, dtype: bool

# %%
countriesPop = pd.Series([8700000,4300000,3000000,2100000, np.nan], index = ['China','Germany','Japan','USA','Omam'])

countriesPop.name = "countriesPop"

pd.isnull(countriesPop).sum()
# Out:
# np.int64(1)

# %%
pd.notnull(countriesPop).sum()
# Out:
# np.int64(4)

# %%
countriesPop2 = pd.Series([8700000,4300000,3000000,2100000, np.nan], index = ['China','Germany','Japan','USA','Omam'])
concat = countriesPop + countriesPop2
print(concat)
countriesPop.name = "countriesPop"
# Out:
# China      17400000.0
# Germany     8600000.0
# Japan       6000000.0
# USA         4200000.0
# Omam              NaN
# dtype: float64

# %%
s = pd.Series({"Mathe":85 , "Science" :90 , "English":78})
print(s[s>80]) #filter values grater than 80
# Out:
# Mathe      85
# Science    90
# dtype: int64

# %%
##################################################################

# %%
s2 = pd.Series([10,None , 30 , None , 50])
#count missing value
print("missing values : ", s2.isna().sum()) 
#fill missing with mean
mean_val = s2.mean()
print("filled series")
s2.fillna(mean_val)
print(s)
# Out:
# missing values :  2
# filled series
# Mathe      85
# Science    90
# English    78
# dtype: int64

# %%
#############################################################

# %%
names = pd.Series(["Ali", "Sara", "Ahmed", "Muna"])

#finde upper casess
print(names.str.upper())
# Out:
# 0      ALI
# 1     SARA
# 2    AHMED
# 3     MUNA
# dtype: str

# %%
# find names with >4 length
print(names[names.str.len() > 4])
# Out:
# 2    Ahmed
# dtype: str

# %%
#################################################################

# %%
s = pd.Series([4,6,8] , index=["a", "b" ,"c"])
s.rename(index={"a" : "x"}, inplace= True)
print(s)
# Out:
# x    4
# b    6
# c    8
# dtype: int64

# %%
s["z"] = 40
print(s)
# Out:
# x     4
# b     6
# c     8
# z    40
# dtype: int64

# %%
#####################################################################

# %%
import pandas as pd
import numpy as np

# %%
s = pd.Series([50,10,30,20,40])
print(s.sort_values())
# Out:
# 1    10
# 3    20
# 2    30
# 4    40
# 0    50
# dtype: int64

# %%
print(s.value_counts())
# Out:
# 50    1
# 10    1
# 30    1
# 20    1
# 40    1
# Name: count, dtype: int64

# %%
################################################
s1 = pd.Series([10, 20, 30])
s2 = pd.Series([15, 15, 35])
print(s1 > s2)
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
print(s2>s1)
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
sales = pd.Series([200, 450, 300, 150, 500], index=["Mon", "Tue", "Wed", "Thu", "Fri"])
#Total sales
print("Total:", sales.sum())

# Average sales
print("Average:", sales.mean())

# Max sales day
print("Highest day:", sales.idxmax())

# Sales > 300
print("Days with sales > 300:")
print(sales[sales > 300])
# Out:
# Total: 1600
# Average: 320.0
# Highest day: Fri
# Days with sales > 300:
# Tue    450
# Fri    500
# dtype: int64
